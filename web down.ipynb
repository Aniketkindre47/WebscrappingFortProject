# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from wordcloud import WordCloud

# %%
#Courtesy Kaustubh ;)

url = 'https://www.treksandtrails.org/blog/treksandtrails-list-of-forts-of-maharashtra/'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html5lib')

rows= soup.find("div",class_ ="textwidget custom-html-widget").find_all("table")

#print(soup.find_all('table'))
soup.findAll('table')[0].findAll('tr')[1].findAll('td')[0]

df=pd.DataFrame(columns=['Region', 'Name','Height'])

x=0
i=0
for i in range(24):
  region=soup.findAll('table')[i].findAll('tr')[1].findAll('td')[0].text
  x=len(soup.find_all('table')[i].findAll('tr'))

  for j in range(x):
    if j==0:
      pass
    else:
      soup.findAll('table')[i].findAll('tr')[j]
      df.loc[len(df.index)] = [region, soup.find_all('table')[i].findAll('tr')[j].findAll('td')[2].text,soup.find_all('table')[i].findAll('tr')[j].findAll('td')[3].text.replace('\'','')]
      
    
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15596/3706189438.py in <module>
#       6 soup = BeautifulSoup(response.content, 'html5lib')
#       7
# ----> 8 rows= soup.find("div",class_ ="textwidget custom-html-widget").find_all("table")
#       9
#      10 #print(soup.find_all('table'))
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15596/286341606.py in <module>
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df1 = df.sort_values(by=["Height"])
df1.tail(16)

# %%
#df2 = df1.iloc[:-15,:]
df2 = df1.drop(index=df1[df1['Height']=='NA'].index)
df2

# %%
df2.dtypes

# %%
df2["Height"] = pd.to_numeric(df2["Height"])
df2

# %%
df3 = df2.sort_values(by=["Height"])
df3.tail(15)

# %%
df3.to_csv("TrekHeight.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15596/3424177236.py in <module>
# ----> 1 df3.to_csv("TrekHeight.csv")
#
# NameError: name 'df3' is not defined

# %%
ddf=pd.read_csv(r'TrekHeight.csv')
ddf
# Out:
#        Region            Name  Height
# 0      KARJAT   Sankshi Fort      800
# 1        ROHA       Avchitgad     977
# 2       DHULE     Songir fort     997
# 3        ROHA         Songiri    1000
# 4        ROHA      Tala Fort     1000
# ..        ...             ...     ...
# 158  IGATPURI       Mandan***    4841
# 159  IGATPURI        Alang***    4852
# 160    BAGLAN     Salota Fort    4986
# 161    BAGLAN     Salher Fort    5140
# 162    JUNNAR   Kalsubai Trek    5400
#
# [163 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np


ddf['Height'] = ddf['Height'].astype('int')
ddf['Name'] = ddf['Name'].astype('str')
ddf['Name'] = ddf['Name'].str.replace('\*\*\*','')
data = ddf.set_index('Name').to_dict()['Height']
print(data)


wc = WordCloud(width=800, height=400, max_words=200).generate_from_frequencies(data)
plt.figure(figsize=(15,13), facecolor="k")
plt.axis("off")
plt.tight_layout(pad=0)
plt.imshow(wc, interpolation='bilinear')
plt.show()
#https://amueller.github.io/word_cloud/auto_examples/a_new_hope.html
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_15596/3970487413.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#
Tikona Fort': 3580, 'Kanheragad/Kanergad': 3582, 'Vasota - Vyaghragad': 3614, 'Nimgiri': 3635, 'Jarandeshwar': 3654, 'Hatgad Fort': 3656, ' Rohida Fort - Vichitragad ': 3661, 'Kunjargad Fort': 3670, 'Harihar Fort': 3676, 'Chandwad': 3691, 'Chaulher Fort - Tilwan Fort': 3702, 'Kanchana Fort': 3722, 'Jivdhan Fort - Kukadeshwar': 3754, 'Kaladgad/Bhairavgad': 3769, 'Kaladgad': 3769, 'Chandangad Fort': 3836, 'Vandangad Fort': 3841, 'Durg': 3855, 'Ahivant Fort': 4024, 'Achala Fort': 4040, 'Javlya Fort': 4056, 'Madhu Makarandgad Fort Trek': 4064, 'Nhavi/Ratangad': 4110, 'Ravlya Fort': 4131, 'Dhakoba': 4148, 'Pandavgad Fort ': 4185, 'Brahmagiri Fort': 4248, 'Ratangad Fort': 4255, 'Anjaneri Fort': 4264, 'Kenjalgad Fort': 4269, 'Mulher Fort ': 4284, 'Sinhagad Fort - Kondana Fort': 4320, 'Aundha/Avandha': 4329, 'Markandeya Fort ': 4370, 'Vajragad': 4422, 'Hargad Fort ': 4460, 'Indrai': 4495, ' Ajoba parvat - Aaja Parvat': 4511, 'Rajgad Fort': 4514, 'Kamalgad Fort': 4522, 'Purandar Fort': 4560, 'Patta Fort - Vishramgad': 4562, ' Raireshwar Fort': 4589, 'Torna Fort - Prachandgad': 4604, 'Saptashrungi gad': 4659, 'Harishchandragad Fort': 4671, 'Hadsar Fort': 4687, 'Mahabaleshwar': 4718, 'Dhodap Fort ': 4761, 'Kulang': 4822, 'Mandan': 4841, 'Alang': 4852, 'Salota Fort': 4986, 'Salher Fort': 5140, 'Kalsubai Trek': 5400}

# %%
from PIL import Image
mh_mask=Image.open('E:\\maharashtra-outline-map.JPG')
mht=np.array(mh_mask)
img = Image.fromarray(mht, "RGBA")
plt.imshow(mht,interpolation='bilinear')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15596/2639646652.py in <module>
#       2 mh_mask=Image.open('E:\\maharashtra-outline-map.JPG')
#       3 mht=np.array(mh_mask)
# ----> 4 img = Image.fromarray(mht, "RGBA")
#       5 plt.imshow(mht,interpolation='bilinear')
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2854             obj = obj.tostring()
#    2855
# -> 2856     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2857
#    2858
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2790         if args[0] in _MAPMODES:
#    2791             im = new(mode, (1, 1))
# -> 2792             im = im._new(core.map_buffer(data, size, decoder_name, 0, args))
#    2793             im.readonly = 1
#    2794             return im
#
# ValueError: buffer is not large enough

# %%
wc = WordCloud(max_words=200,mask=mht,random_state=42, width=mht.shape[1],
               height=mht.shape[0],background_color="white",contour_width=3,contour_color='steelblue',f).generate_from_frequencies(data)
plt.figure(facecolor="k")
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(mht, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_15596/741781546.py", line 2
#     height=mht.shape[0],background_color="white",contour_width=3,contour_color='steelblue',f).generate_from_frequencies(data)
#                                                                                             ^
# SyntaxError: positional argument follows keyword argument
